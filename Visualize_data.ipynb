# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Loading  dataset 
df = pd.read_csv('wavelet_metrics.csv')  
print(df.head())
# Out:
#     Data      MAV_A5  Avg.Power_A5       SD_A5  MAV_Ratio_A5      MAV_D3  \
# 0  S0010  151.436719  37369.120351  187.446547      0.779413  186.739267
# 1  S0011  144.744433  35113.924552  180.949640      1.044971  179.396085
# 2  S0012  156.938298  40952.884466  198.482040      0.873709  203.521622
# 3  S0013  184.805879  50715.973221  218.815569      1.022595  160.496149
# 4  S0014  126.052444  26097.909667  154.514342      0.467648  195.071566
#
#    Avg.Power_D3       SD_D3  MAV_Ratio_D3      MAV_D4  Avg.Power_D4  \
# 0  74066.536229  272.151668      2.836279  161.179040  45633.086354
# 1  67871.229901  260.520817      2.539925  157.109493  42765.822436
# 2  83269.950633  288.565332      2.909602  166.820183  48052.083805
# 3  64892.709992  254.740266      2.447485  144.834861  37379.410143
# 4  74329.254022  272.633870      3.308986  175.284403  54417.522148
#
#         SD_D4  MAV_Ratio_D4      MAV_D5   Avg.Power_D5       SD_D5  \
# 0  213.619019      0.863123  194.295963   61695.131423  248.385046
# 1  206.798990      0.875769  138.515304   36097.406162  189.988759
# 2  219.207713      0.819668  179.623060   51387.183336  226.687383
# 3  193.337428      0.902420  180.722465   52113.029909  228.282386
# 4  233.275311      0.898565  269.545846  103874.607069  322.295836
#
#    MAV_Ratio_D5  label
# 0      1.205467      0
# 1      0.881648      0
# 2      1.076747      0
# 3      1.247783      0
# 4      1.537763      0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('wavelet_mat.csv')

# List all feature columns (excluding 'Data' and 'label')
features = data.columns[1:-1]  

for i, feature in enumerate(features):
    plt.figure(figsize=(6, 4))
    plt.hist(data[feature], bins=30, edgecolor='black', alpha=0.7)
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()
